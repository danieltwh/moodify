# %%
import numpy as np
#import pandas as pd

from tensorflow.keras.layers import Conv2D, BatchNormalization, MaxPool2D, Flatten, Dense, Input, ReLU, Dropout
import tensorflow.keras as keras
from tensorflow.keras import Model
from tensorflow.keras.callbacks import ModelCheckpoint
from PIL import Image

from ultralytics import YOLO

# %%
#import data
#read the data
#The data is read from the directory and each batch can be thought of as a set of labels and datapoints
#Might need to change the directory depending on where

#50
train = keras.utils.image_dataset_from_directory(
    directory='../../data/Faces',
    labels='inferred',
    label_mode='categorical',
    batch_size=140,
    image_size=(1000, 1000),
    validation_split = 0.2,
    subset = 'training',
    seed = 50,
    class_names = ['Happy' ,'Sad', 'Neutral']
    )

validation = keras.utils.image_dataset_from_directory(
    directory='../../data/Faces',
    labels='inferred',
    label_mode='categorical',
    batch_size=140,
    image_size=(1000, 1000),
    validation_split = 0.2,
    subset = 'validation',
    seed = 50,
    class_names = ['Happy', 'Sad', 'Neutral']
    )
# Out:
# Found 66 files belonging to 3 classes.
# Using 53 files for training.
# Found 66 files belonging to 3 classes.
# Using 13 files for validation.

# %%
#convert images to numpy
train_processed_numpy = train.as_numpy_iterator()
validation_processed_numpy = validation.as_numpy_iterator()

X_train, y_train = train_processed_numpy.next()
X_val, y_val = validation_processed_numpy.next()

# %%
#convert the images to cropped faces
face_classifier = YOLO("../../app/src/face_detection/model/yolov8n-face.pt")

X_cropped_train = []
y_train_cropped = []
n_training = X_train.shape[0]

for i in range(n_training):
    face = X_train[i]
    faces = face_classifier.predict(face)
    boxes = faces[0].boxes.xyxy.tolist()
    if boxes:
        
        #extract the face based on the output from the YOLOv8 model        
        left, bottom, right, top = boxes[0]
        cropped_face = face[int(bottom):int(top), int(left):int(right)]
        #resize cropped face to a std shape, 100x100 for now but can adjust this
        pil_face = Image.fromarray(np.uint8(cropped_face))
        pil_face = pil_face.resize((48, 48))
        numpy_cropped_face = np.array(pil_face)
        #append this to the new list containing all cropped faces
        X_cropped_train.append(numpy_cropped_face)
        y_train_cropped.append(y_train[i])

X_val_cropped = []
y_val_cropped = []
n_val = X_val.shape[0]
for i in range(n_val):
    face = X_val[i]
    faces = face_classifier.predict(face)
    boxes = faces[0].boxes.xyxy.tolist()
    if boxes:
        
        #extract the face based on the output from the YOLOv8 model        
        left, bottom, right, top = boxes[0]
        cropped_face = face[int(bottom):int(top), int(left):int(right)]
        #resize cropped face to a std shape, 100x100 for now but can adjust this
        pil_face = Image.fromarray(np.uint8(cropped_face))
        pil_face = pil_face.resize((48, 48))
        numpy_cropped_face = np.array(pil_face)
        #append this to the new list containing all cropped faces
        X_val_cropped.append(numpy_cropped_face)
        y_val_cropped.append(y_val[i])
# Out:
# 0: 640x640 1 face, 104.6ms
# Speed: 8.1ms preprocess, 104.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 100.1ms
# Speed: 14.6ms preprocess, 100.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 99.8ms
# Speed: 0.8ms preprocess, 99.8ms inference, 15.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 99.3ms
# Speed: 0.0ms preprocess, 99.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 75.9ms
# Speed: 2.2ms preprocess, 75.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 100.0ms
# Speed: 0.0ms preprocess, 100.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 83.2ms
# Speed: 16.6ms preprocess, 83.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 83.2ms
# Speed: 16.8ms preprocess, 83.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 100.1ms
# Speed: 0.7ms preprocess, 100.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 85.0ms
# Speed: 15.0ms preprocess, 85.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 81.5ms
# Speed: 16.7ms preprocess, 81.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 68.3ms
# Speed: 15.0ms preprocess, 68.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 83.0ms
# Speed: 5.3ms preprocess, 83.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 92.4ms
# Speed: 0.0ms preprocess, 92.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 83.2ms
# Speed: 2.3ms preprocess, 83.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 66.6ms
# Speed: 16.6ms preprocess, 66.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 83.0ms
# Speed: 5.3ms preprocess, 83.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 75.9ms
# Speed: 19.0ms preprocess, 75.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 88.9ms
# Speed: 0.0ms preprocess, 88.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 75.7ms
# Speed: 18.9ms preprocess, 75.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 70.3ms
# Speed: 16.6ms preprocess, 70.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 87.0ms
# Speed: 13.0ms preprocess, 87.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 66.9ms
# Speed: 12.9ms preprocess, 66.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 63.4ms
# Speed: 19.8ms preprocess, 63.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 85.9ms
# Speed: 0.0ms preprocess, 85.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 65.9ms
# Speed: 13.6ms preprocess, 65.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 86.3ms
# Speed: 0.0ms preprocess, 86.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 83.3ms
# Speed: 0.0ms preprocess, 83.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 84.4ms
# Speed: 15.7ms preprocess, 84.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 85.3ms
# Speed: 15.7ms preprocess, 85.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 78.3ms
# Speed: 0.0ms preprocess, 78.3ms inference, 15.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 79.0ms
# Speed: 1.9ms preprocess, 79.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 83.3ms
# Speed: 0.0ms preprocess, 83.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 84.9ms
# Speed: 0.0ms preprocess, 84.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 72.7ms
# Speed: 15.7ms preprocess, 72.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 86.9ms
# Speed: 13.2ms preprocess, 86.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 104.0ms
# Speed: 11.5ms preprocess, 104.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 93.0ms
# Speed: 7.0ms preprocess, 93.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 88.3ms
# Speed: 8.9ms preprocess, 88.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 109.0ms
# Speed: 0.0ms preprocess, 109.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 98.3ms
# Speed: 0.0ms preprocess, 98.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 83.8ms
# Speed: 16.7ms preprocess, 83.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 97.8ms
# Speed: 16.3ms preprocess, 97.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 97.1ms
# Speed: 0.0ms preprocess, 97.1ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 99.7ms
# Speed: 0.0ms preprocess, 99.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 95.4ms
# Speed: 0.0ms preprocess, 95.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 81.7ms
# Speed: 15.7ms preprocess, 81.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 87.0ms
# Speed: 15.7ms preprocess, 87.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 89.3ms
# Speed: 0.0ms preprocess, 89.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 62.8ms
# Speed: 15.7ms preprocess, 62.8ms inference, 15.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 82.5ms
# Speed: 0.0ms preprocess, 82.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 72.4ms
# Speed: 15.6ms preprocess, 72.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 86.5ms
# Speed: 15.6ms preprocess, 86.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 85.3ms
# Speed: 3.6ms preprocess, 85.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 68.8ms
# Speed: 13.0ms preprocess, 68.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 84.1ms
# Speed: 0.7ms preprocess, 84.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 68.7ms
# Speed: 14.1ms preprocess, 68.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 82.9ms
# Speed: 2.2ms preprocess, 82.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 83.6ms
# Speed: 15.8ms preprocess, 83.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 105.2ms
# Speed: 17.4ms preprocess, 105.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 82.1ms
# Speed: 17.4ms preprocess, 82.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 85.5ms
# Speed: 13.2ms preprocess, 85.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 116.6ms
# Speed: 16.9ms preprocess, 116.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 161.1ms
# Speed: 16.8ms preprocess, 161.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 181.5ms
# Speed: 18.4ms preprocess, 181.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 167.0ms
# Speed: 17.4ms preprocess, 167.0ms inference, 15.0ms postprocess per image at shape (1, 3, 640, 640)

# %%
#convert data into neural net input format

X_cropped_train = np.array(X_cropped_train)
y_train_cropped = np.array(y_train_cropped)
X_val_cropped = np.array(X_val_cropped)
y_val_cropped = np.array(y_val_cropped)

# %%
#first convolutional layer
#source of archi: https://cs230.stanford.edu/projects_winter_2020/reports/32610274.pdf

default_filters = 32

input_x = Input(shape = (48, 48, 3))

conv_1 = Conv2D(filters = default_filters, kernel_size = (3, 3), name = 'conv_1', padding = 'same',activation='relu' ,data_format='channels_last')(input_x)
batch_norm1 = BatchNormalization(name = 'batch_norm1')(conv_1)
max_pool1 = MaxPool2D(name = 'max_pool1', pool_size = (2,2), strides = (2,2))(batch_norm1)
drop_out1 = Dropout(0.5)(max_pool1)

#second convolutional layer 
conv2 = Conv2D(filters = 2 * default_filters, kernel_size = (3,3), name = 'conv_2', padding = 'same', activation = 'relu')(drop_out1)
batch_norm2 = BatchNormalization(name = 'batch_norm2')(conv2)
max_pool2 = MaxPool2D(name = 'max_pool2', pool_size = (2,2), strides = (2,2))(batch_norm2)
dropout_2 = Dropout(0.5)(max_pool2)




#third convolutional layer
conv3 = Conv2D(filters = 2 * 2 * default_filters, kernel_size = (3,3), name = 'conv_3', padding = 'same', activation = 'relu')(dropout_2)
batch_norm3 = BatchNormalization(name = 'batch_norm3')(conv3)

max_pool3 = MaxPool2D(name = 'max_pool3', pool_size = (2,2), strides = (2,2))(batch_norm3)
dropout_3 = Dropout(0.5)(max_pool3)



flat = Flatten()(dropout_3)

dense1 = Dense(128, activation = 'relu', name = 'dense_1')(flat)
drop_out_dense1 = Dropout(0.4)(dense1)
dense2 = Dense(128, activation = 'relu', name = 'dense_2')(drop_out_dense1)
drop_out_dense2 = Dropout(0.4)(dense2)
#final softmax layer
dense3 = Dense(64, activation = 'relu', name = 'dense_3')(drop_out_dense2)
drop_out_dense3 = Dropout(0.5)(dense3)

#6 outputs for the 6 classes
output = Dense(3, activation = 'softmax', name = 'output')(drop_out_dense3)


# In[11]:

# %%
checkpoint = ModelCheckpoint(filepath = 'cnn_scratch.keras')


# In[ ]:


model = Model(input_x, output)

model.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['acc'])

model.fit(x = X_cropped_train/255, y = y_train_cropped, epochs = 100, validation_data = (X_val_cropped/255, y_val_cropped), callbacks = [checkpoint])
# Out:
# Epoch 1/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 268ms/step - acc: 0.3349 - loss: 3.0139 - val_acc: 0.3846 - val_loss: 1.0981
# Epoch 2/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - acc: 0.3221 - loss: 3.1685 - val_acc: 0.3077 - val_loss: 1.0994
# Epoch 3/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - acc: 0.3662 - loss: 3.8649 - val_acc: 0.3077 - val_loss: 1.0983
# Epoch 4/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - acc: 0.2500 - loss: 3.4627 - val_acc: 0.2308 - val_loss: 1.0994
# Epoch 5/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - acc: 0.2885 - loss: 3.3915 - val_acc: 0.2308 - val_loss: 1.1035
# Epoch 6/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - acc: 0.3838 - loss: 2.3278 - val_acc: 0.3077 - val_loss: 1.1078
# Epoch 7/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - acc: 0.1803 - loss: 2.9499 - val_acc: 0.5385 - val_loss: 1.1139
# Epoch 8/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - acc: 0.5569 - loss: 1.6331 - val_acc: 0.3077 - val_loss: 1.1217
# Epoch 9/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - acc: 0.3582 - loss: 1.9159 - val_acc: 0.3077 - val_loss: 1.1333
# Epoch 10/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - acc: 0.2035 - loss: 2.3528 - val_acc: 0.3077 - val_loss: 1.1451
# Epoch 11/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - acc: 0.3478 - loss: 1.4773 - val_acc: 0.3077 - val_loss: 1.1566
# Epoch 12/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - acc: 0.4046 - loss: 1.5010 - val_acc: 0.3077 - val_loss: 1.1713
# Epoch 13/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - acc: 0.4431 - loss: 1.4058 - val_acc: 0.3077 - val_loss: 1.1806
# Epoch 14/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - acc: 0.2628 - loss: 1.3895 - val_acc: 0.3077 - val_loss: 1.1863
# Epoch 15/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - acc: 0.4175 - loss: 1.3205 - val_acc: 0.3077 - val_loss: 1.1996
# Epoch 16/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - acc: 0.2732 - loss: 1.3949 - val_acc: 0.3077 - val_loss: 1.2181
# Epoch 17/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - acc: 0.4175 - loss: 1.1926 - val_acc: 0.3077 - val_loss: 1.2312
# Epoch 18/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - acc: 0.4407 - loss: 1.1734 - val_acc: 0.3077 - val_loss: 1.2447
# Epoch 19/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - acc: 0.4151 - loss: 1.2775 - val_acc: 0.3077 - val_loss: 1.2596
# Epoch 20/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - acc: 0.3221 - loss: 1.2257 - val_acc: 0.3077 - val_loss: 1.2808
# Epoch 21/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - acc: 0.4255 - loss: 1.1934 - val_acc: 0.3077 - val_loss: 1.3008
# Epoch 22/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - acc: 0.2268 - loss: 1.2231 - val_acc: 0.3077 - val_loss: 1.3187
# Epoch 23/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - acc: 0.3710 - loss: 1.0426 - val_acc: 0.3077 - val_loss: 1.3370
# Epoch 24/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - acc: 0.2420 - loss: 1.2107 - val_acc: 0.3077 - val_loss: 1.3568
# Epoch 25/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - acc: 0.3734 - loss: 1.1828 - val_acc: 0.3077 - val_loss: 1.3670
# Epoch 26/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - acc: 0.3998 - loss: 1.0652 - val_acc: 0.3077 - val_loss: 1.3738
# Epoch 27/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step - acc: 0.4407 - loss: 1.0624 - val_acc: 0.3077 - val_loss: 1.3796
# Epoch 28/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 248ms/step - acc: 0.4744 - loss: 1.1071 - val_acc: 0.3077 - val_loss: 1.3853
# Epoch 29/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - acc: 0.2837 - loss: 1.1225 - val_acc: 0.3077 - val_loss: 1.3971
# Epoch 30/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - acc: 0.1907 - loss: 1.2221 - val_acc: 0.3077 - val_loss: 1.4163
# Epoch 31/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - acc: 0.4487 - loss: 1.0705 - val_acc: 0.3077 - val_loss: 1.4353
# Epoch 32/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - acc: 0.4511 - loss: 1.0939 - val_acc: 0.3077 - val_loss: 1.4495
# Epoch 33/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - acc: 0.3558 - loss: 1.1031 - val_acc: 0.3077 - val_loss: 1.4718
# Epoch 34/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - acc: 0.4872 - loss: 1.0496 - val_acc: 0.3077 - val_loss: 1.5008
# Epoch 35/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step - acc: 0.4022 - loss: 1.0555 - val_acc: 0.3077 - val_loss: 1.5229
# Epoch 36/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - acc: 0.2396 - loss: 1.1142 - val_acc: 0.3077 - val_loss: 1.5443
# Epoch 37/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - acc: 0.3942 - loss: 1.1194 - val_acc: 0.3077 - val_loss: 1.5556
# Epoch 38/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - acc: 0.3117 - loss: 1.1052 - val_acc: 0.3077 - val_loss: 1.5619
# Epoch 39/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - acc: 0.3069 - loss: 1.0909 - val_acc: 0.3077 - val_loss: 1.5613
# Epoch 40/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - acc: 0.2861 - loss: 1.0920 - val_acc: 0.3077 - val_loss: 1.5542
# Epoch 41/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - acc: 0.3710 - loss: 1.0472 - val_acc: 0.3077 - val_loss: 1.5436
# Epoch 42/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - acc: 0.3534 - loss: 1.0714 - val_acc: 0.3077 - val_loss: 1.5305
# Epoch 43/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - acc: 0.3734 - loss: 1.0072 - val_acc: 0.3077 - val_loss: 1.5239
# Epoch 44/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - acc: 0.4872 - loss: 1.0799 - val_acc: 0.3077 - val_loss: 1.5199
# Epoch 45/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - acc: 0.4407 - loss: 1.1652 - val_acc: 0.3077 - val_loss: 1.5081
# Epoch 46/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - acc: 0.3686 - loss: 1.1817 - val_acc: 0.3077 - val_loss: 1.4933
# Epoch 47/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - acc: 0.4535 - loss: 1.0830 - val_acc: 0.3077 - val_loss: 1.4886
# Epoch 48/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - acc: 0.3686 - loss: 1.1026 - val_acc: 0.3077 - val_loss: 1.4950
# Epoch 49/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - acc: 0.3325 - loss: 1.1470 - val_acc: 0.3077 - val_loss: 1.4950
# Epoch 50/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - acc: 0.4303 - loss: 1.1107 - val_acc: 0.3077 - val_loss: 1.4864
# Epoch 51/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - acc: 0.4720 - loss: 1.0310 - val_acc: 0.3077 - val_loss: 1.4785
# Epoch 52/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - acc: 0.4127 - loss: 1.0637 - val_acc: 0.3077 - val_loss: 1.4850
# Epoch 53/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - acc: 0.3325 - loss: 1.1084 - val_acc: 0.3077 - val_loss: 1.4901
# Epoch 54/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - acc: 0.4768 - loss: 1.0987 - val_acc: 0.3077 - val_loss: 1.4904
# Epoch 55/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - acc: 0.3069 - loss: 1.0809 - val_acc: 0.3077 - val_loss: 1.4912
# Epoch 56/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - acc: 0.3814 - loss: 1.0847 - val_acc: 0.3077 - val_loss: 1.4898
# Epoch 57/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - acc: 0.4896 - loss: 0.9874 - val_acc: 0.3077 - val_loss: 1.4888
# Epoch 58/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - acc: 0.2861 - loss: 1.1372 - val_acc: 0.3077 - val_loss: 1.5013
# Epoch 59/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - acc: 0.2396 - loss: 1.1802 - val_acc: 0.3077 - val_loss: 1.5077
# Epoch 60/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - acc: 0.4639 - loss: 1.0951 - val_acc: 0.3077 - val_loss: 1.5013
# Epoch 61/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - acc: 0.4511 - loss: 1.0518 - val_acc: 0.3077 - val_loss: 1.4712
# Epoch 62/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - acc: 0.3478 - loss: 1.1495 - val_acc: 0.3077 - val_loss: 1.4537
# Epoch 63/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - acc: 0.4119 - loss: 1.0591 - val_acc: 0.3077 - val_loss: 1.4302
# Epoch 64/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - acc: 0.3710 - loss: 1.0823 - val_acc: 0.3077 - val_loss: 1.3948
# Epoch 65/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - acc: 0.3710 - loss: 1.0594 - val_acc: 0.3077 - val_loss: 1.3755
# Epoch 66/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - acc: 0.4175 - loss: 1.1021 - val_acc: 0.3077 - val_loss: 1.3615
# Epoch 67/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - acc: 0.3454 - loss: 1.0984 - val_acc: 0.3077 - val_loss: 1.3735
# Epoch 68/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - acc: 0.5152 - loss: 0.9739 - val_acc: 0.3077 - val_loss: 1.4154
# Epoch 69/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - acc: 0.2780 - loss: 1.1296 - val_acc: 0.3077 - val_loss: 1.4928
# Epoch 70/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - acc: 0.3454 - loss: 1.0991 - val_acc: 0.3077 - val_loss: 1.5616
# Epoch 71/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - acc: 0.3373 - loss: 1.0479 - val_acc: 0.3077 - val_loss: 1.6273
# Epoch 72/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - acc: 0.4535 - loss: 1.0237 - val_acc: 0.3077 - val_loss: 1.6977
# Epoch 73/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - acc: 0.3918 - loss: 1.0043 - val_acc: 0.3077 - val_loss: 1.7517
# Epoch 74/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - acc: 0.3558 - loss: 1.0689 - val_acc: 0.3077 - val_loss: 1.7978
# Epoch 75/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - acc: 0.4407 - loss: 1.0213 - val_acc: 0.3077 - val_loss: 1.8276
# Epoch 76/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - acc: 0.3942 - loss: 1.0381 - val_acc: 0.3077 - val_loss: 1.8360
# Epoch 77/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - acc: 0.4744 - loss: 1.0670 - val_acc: 0.3077 - val_loss: 1.8353
# Epoch 78/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - acc: 0.3349 - loss: 1.0362 - val_acc: 0.3077 - val_loss: 1.8206
# Epoch 79/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - acc: 0.3141 - loss: 1.0939 - val_acc: 0.3077 - val_loss: 1.7879
# Epoch 80/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - acc: 0.3894 - loss: 1.0465 - val_acc: 0.3077 - val_loss: 1.7469
# Epoch 81/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - acc: 0.5232 - loss: 0.9877 - val_acc: 0.3077 - val_loss: 1.7154
# Epoch 82/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - acc: 0.4872 - loss: 0.9805 - val_acc: 0.3077 - val_loss: 1.6659
# Epoch 83/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - acc: 0.4535 - loss: 0.9891 - val_acc: 0.3077 - val_loss: 1.6074
# Epoch 84/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - acc: 0.3894 - loss: 1.0588 - val_acc: 0.3077 - val_loss: 1.5389
# Epoch 85/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - acc: 0.4511 - loss: 1.0315 - val_acc: 0.3077 - val_loss: 1.5066
# Epoch 86/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - acc: 0.4920 - loss: 0.9919 - val_acc: 0.3077 - val_loss: 1.5000
# Epoch 87/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - acc: 0.3245 - loss: 1.0779 - val_acc: 0.3077 - val_loss: 1.5086
# Epoch 88/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - acc: 0.4383 - loss: 1.0042 - val_acc: 0.3077 - val_loss: 1.5181
# Epoch 89/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - acc: 0.3301 - loss: 1.0463 - val_acc: 0.3077 - val_loss: 1.5049
# Epoch 90/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - acc: 0.2861 - loss: 1.0818 - val_acc: 0.3077 - val_loss: 1.5066
# Epoch 91/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - acc: 0.3814 - loss: 1.0522 - val_acc: 0.3077 - val_loss: 1.5213
# Epoch 92/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - acc: 0.4976 - loss: 1.0211 - val_acc: 0.3077 - val_loss: 1.5347
# Epoch 93/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - acc: 0.4976 - loss: 1.0296 - val_acc: 0.3077 - val_loss: 1.5127
# Epoch 94/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - acc: 0.4768 - loss: 1.0115 - val_acc: 0.3077 - val_loss: 1.4682
# Epoch 95/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - acc: 0.4615 - loss: 0.9343 - val_acc: 0.3077 - val_loss: 1.4263
# Epoch 96/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - acc: 0.5337 - loss: 1.0438 - val_acc: 0.3077 - val_loss: 1.3778
# Epoch 97/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - acc: 0.5256 - loss: 0.9316 - val_acc: 0.3077 - val_loss: 1.3475
# Epoch 98/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - acc: 0.4046 - loss: 1.0124 - val_acc: 0.3077 - val_loss: 1.3348
# Epoch 99/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - acc: 0.4768 - loss: 1.0056 - val_acc: 0.3077 - val_loss: 1.3163
# Epoch 100/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - acc: 0.4463 - loss: 1.0615 - val_acc: 0.3077 - val_loss: 1.3098
