# %%
import numpy as np
#import pandas as pd

from tensorflow.keras.layers import Conv2D, BatchNormalization, MaxPool2D, Flatten, Dense, Input, ReLU, Dropout
import tensorflow.keras as keras
from tensorflow.keras import Model
from tensorflow.keras.callbacks import ModelCheckpoint
from PIL import Image

from ultralytics import YOLO

# %%
#import data
#read the data
#The data is read from the directory and each batch can be thought of as a set of labels and datapoints
#Might need to change the directory depending on where

#50
train = keras.utils.image_dataset_from_directory(
    directory='../../data/Faces',
    labels='inferred',
    label_mode='categorical',
    batch_size=140,
    image_size=(1000, 1000),
    validation_split = 0.2,
    subset = 'training',
    seed = 50
    )

validation = keras.utils.image_dataset_from_directory(
    directory='../../data/Faces',
    labels='inferred',
    label_mode='categorical',
    batch_size=140,
    image_size=(1000, 1000),
    validation_split = 0.2,
    subset = 'validation',
    seed = 50
    )
# Out:
# Found 140 files belonging to 6 classes.
# Using 112 files for training.
# Found 140 files belonging to 6 classes.
# Using 28 files for validation.

# %%
#convert images to numpy
train_processed_numpy = train.as_numpy_iterator()
validation_processed_numpy = validation.as_numpy_iterator()

X_train, y_train = train_processed_numpy.next()
X_val, y_val = validation_processed_numpy.next()

# %%
#convert the images to cropped faces
face_classifier = YOLO("../../app/src/face_detection/model/yolov8n-face.pt")

X_cropped_train = []
y_train_cropped = []

for i in range(112):
    face = X_train[i]
    faces = face_classifier.predict(face)
    boxes = faces[0].boxes.xyxy.tolist()
    if boxes:
        
        #extract the face based on the output from the YOLOv8 model        
        left, bottom, right, top = boxes[0]
        cropped_face = face[int(bottom):int(top), int(left):int(right)]
        #resize cropped face to a std shape, 100x100 for now but can adjust this
        pil_face = Image.fromarray(np.uint8(cropped_face))
        pil_face = pil_face.resize((75, 75))
        numpy_cropped_face = np.array(pil_face)
        #append this to the new list containing all cropped faces
        X_cropped_train.append(numpy_cropped_face)
        y_train_cropped.append(y_train[i])

X_val_cropped = []
y_val_cropped = []

for i in range(28):
    face = X_val[i]
    faces = face_classifier.predict(face)
    boxes = faces[0].boxes.xyxy.tolist()
    if boxes:
        
        #extract the face based on the output from the YOLOv8 model        
        left, bottom, right, top = boxes[0]
        cropped_face = face[int(bottom):int(top), int(left):int(right)]
        #resize cropped face to a std shape, 100x100 for now but can adjust this
        pil_face = Image.fromarray(np.uint8(cropped_face))
        pil_face = pil_face.resize((75, 75))
        numpy_cropped_face = np.array(pil_face)
        #append this to the new list containing all cropped faces
        X_val_cropped.append(numpy_cropped_face)
        y_val_cropped.append(y_val[i])
# Out:
# 0: 640x640 1 face, 125.9ms
# Speed: 8.6ms preprocess, 125.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 86.9ms
# Speed: 14.1ms preprocess, 86.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 87.4ms
# Speed: 15.0ms preprocess, 87.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 82.9ms
# Speed: 8.0ms preprocess, 82.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 86.0ms
# Speed: 7.0ms preprocess, 86.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 99.4ms
# Speed: 7.0ms preprocess, 99.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 93.1ms
# Speed: 7.0ms preprocess, 93.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 89.9ms
# Speed: 7.0ms preprocess, 89.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 94.3ms
# Speed: 7.0ms preprocess, 94.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 81.5ms
# Speed: 7.0ms preprocess, 81.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 75.5ms
# Speed: 7.0ms preprocess, 75.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 75.2ms
# Speed: 8.0ms preprocess, 75.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 83.1ms
# Speed: 8.0ms preprocess, 83.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 faces, 78.9ms
# Speed: 7.0ms preprocess, 78.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 80.6ms
# Speed: 8.0ms preprocess, 80.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 86.9ms
# Speed: 7.0ms preprocess, 86.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 86.4ms
# Speed: 9.0ms preprocess, 86.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 88.1ms
# Speed: 7.0ms preprocess, 88.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 87.5ms
# Speed: 7.0ms preprocess, 87.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 81.6ms
# Speed: 8.0ms preprocess, 81.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 76.6ms
# Speed: 7.1ms preprocess, 76.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 76.7ms
# Speed: 7.0ms preprocess, 76.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 79.0ms
# Speed: 8.0ms preprocess, 79.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 80.8ms
# Speed: 9.0ms preprocess, 80.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 77.1ms
# Speed: 8.0ms preprocess, 77.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 74.4ms
# Speed: 8.0ms preprocess, 74.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 77.5ms
# Speed: 7.0ms preprocess, 77.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 89.7ms
# Speed: 8.0ms preprocess, 89.7ms inference, 8.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 90.5ms
# Speed: 11.3ms preprocess, 90.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 79.1ms
# Speed: 7.0ms preprocess, 79.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 79.5ms
# Speed: 7.0ms preprocess, 79.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 74.5ms
# Speed: 10.0ms preprocess, 74.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 78.5ms
# Speed: 9.0ms preprocess, 78.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 90.4ms
# Speed: 7.0ms preprocess, 90.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 81.4ms
# Speed: 9.4ms preprocess, 81.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 80.0ms
# Speed: 7.0ms preprocess, 80.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 86.8ms
# Speed: 9.3ms preprocess, 86.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 92.0ms
# Speed: 8.2ms preprocess, 92.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 94.5ms
# Speed: 7.0ms preprocess, 94.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 83.1ms
# Speed: 9.2ms preprocess, 83.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 79.0ms
# Speed: 7.0ms preprocess, 79.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 82.0ms
# Speed: 8.5ms preprocess, 82.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 74.5ms
# Speed: 7.0ms preprocess, 74.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 79.5ms
# Speed: 8.0ms preprocess, 79.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 90.5ms
# Speed: 9.0ms preprocess, 90.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 104.5ms
# Speed: 10.0ms preprocess, 104.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 125.5ms
# Speed: 11.5ms preprocess, 125.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 136.5ms
# Speed: 11.0ms preprocess, 136.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 153.5ms
# Speed: 13.0ms preprocess, 153.5ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 156.1ms
# Speed: 15.0ms preprocess, 156.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 151.3ms
# Speed: 15.0ms preprocess, 151.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 160.1ms
# Speed: 15.0ms preprocess, 160.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 150.7ms
# Speed: 15.0ms preprocess, 150.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 206.6ms
# Speed: 14.3ms preprocess, 206.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 181.7ms
# Speed: 22.0ms preprocess, 181.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 221.8ms
# Speed: 16.0ms preprocess, 221.8ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 176.9ms
# Speed: 17.5ms preprocess, 176.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 218.1ms
# Speed: 18.5ms preprocess, 218.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 154.8ms
# Speed: 17.0ms preprocess, 154.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 147.1ms
# Speed: 15.0ms preprocess, 147.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 144.5ms
# Speed: 14.0ms preprocess, 144.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 153.1ms
# Speed: 15.9ms preprocess, 153.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 156.1ms
# Speed: 16.0ms preprocess, 156.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 150.6ms
# Speed: 15.0ms preprocess, 150.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 168.3ms
# Speed: 15.5ms preprocess, 168.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 170.5ms
# Speed: 19.0ms preprocess, 170.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 151.5ms
# Speed: 15.0ms preprocess, 151.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 147.1ms
# Speed: 16.0ms preprocess, 147.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 149.2ms
# Speed: 13.0ms preprocess, 149.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 159.9ms
# Speed: 16.0ms preprocess, 159.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 150.5ms
# Speed: 15.0ms preprocess, 150.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 155.7ms
# Speed: 15.0ms preprocess, 155.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 166.1ms
# Speed: 18.0ms preprocess, 166.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 165.9ms
# Speed: 21.0ms preprocess, 165.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 159.5ms
# Speed: 15.0ms preprocess, 159.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 271.2ms
# Speed: 17.0ms preprocess, 271.2ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 179.1ms
# Speed: 19.0ms preprocess, 179.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 159.1ms
# Speed: 16.0ms preprocess, 159.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 155.9ms
# Speed: 15.0ms preprocess, 155.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 168.4ms
# Speed: 17.4ms preprocess, 168.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 144.1ms
# Speed: 14.0ms preprocess, 144.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 149.4ms
# Speed: 14.0ms preprocess, 149.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 152.1ms
# Speed: 16.0ms preprocess, 152.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 151.2ms
# Speed: 14.0ms preprocess, 151.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 135.5ms
# Speed: 13.0ms preprocess, 135.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 164.1ms
# Speed: 14.0ms preprocess, 164.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 192.1ms
# Speed: 16.0ms preprocess, 192.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 173.3ms
# Speed: 18.0ms preprocess, 173.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 152.6ms
# Speed: 15.0ms preprocess, 152.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 174.1ms
# Speed: 13.0ms preprocess, 174.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 177.1ms
# Speed: 16.0ms preprocess, 177.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 174.6ms
# Speed: 16.0ms preprocess, 174.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 166.3ms
# Speed: 16.3ms preprocess, 166.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 160.0ms
# Speed: 16.0ms preprocess, 160.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 158.7ms
# Speed: 16.4ms preprocess, 158.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 196.1ms
# Speed: 14.0ms preprocess, 196.1ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 195.2ms
# Speed: 22.0ms preprocess, 195.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 164.6ms
# Speed: 16.0ms preprocess, 164.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 143.4ms
# Speed: 15.0ms preprocess, 143.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 160.9ms
# Speed: 14.0ms preprocess, 160.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 187.5ms
# Speed: 18.0ms preprocess, 187.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 231.1ms
# Speed: 17.0ms preprocess, 231.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 174.5ms
# Speed: 16.5ms preprocess, 174.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 163.5ms
# Speed: 18.6ms preprocess, 163.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 162.5ms
# Speed: 15.5ms preprocess, 162.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 192.7ms
# Speed: 15.0ms preprocess, 192.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 169.1ms
# Speed: 18.6ms preprocess, 169.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 144.2ms
# Speed: 16.2ms preprocess, 144.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 132.9ms
# Speed: 13.0ms preprocess, 132.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 132.5ms
# Speed: 13.0ms preprocess, 132.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 134.1ms
# Speed: 13.0ms preprocess, 134.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 132.5ms
# Speed: 12.0ms preprocess, 132.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 136.4ms
# Speed: 13.0ms preprocess, 136.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 146.1ms
# Speed: 14.0ms preprocess, 146.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 146.2ms
# Speed: 14.0ms preprocess, 146.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 149.5ms
# Speed: 13.0ms preprocess, 149.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 151.4ms
# Speed: 13.0ms preprocess, 151.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 148.2ms
# Speed: 13.0ms preprocess, 148.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 155.0ms
# Speed: 14.7ms preprocess, 155.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 153.2ms
# Speed: 14.0ms preprocess, 153.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 172.6ms
# Speed: 13.0ms preprocess, 172.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 177.4ms
# Speed: 17.0ms preprocess, 177.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 149.8ms
# Speed: 15.5ms preprocess, 149.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 150.0ms
# Speed: 16.0ms preprocess, 150.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 141.1ms
# Speed: 12.6ms preprocess, 141.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 142.3ms
# Speed: 13.1ms preprocess, 142.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 152.8ms
# Speed: 14.0ms preprocess, 152.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 224.8ms
# Speed: 16.3ms preprocess, 224.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 157.1ms
# Speed: 18.1ms preprocess, 157.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 146.7ms
# Speed: 15.1ms preprocess, 146.7ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 177.4ms
# Speed: 19.2ms preprocess, 177.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 155.1ms
# Speed: 15.4ms preprocess, 155.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 206.4ms
# Speed: 15.3ms preprocess, 206.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 166.4ms
# Speed: 18.0ms preprocess, 166.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 153.9ms
# Speed: 15.0ms preprocess, 153.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 140.6ms
# Speed: 14.2ms preprocess, 140.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 143.9ms
# Speed: 13.2ms preprocess, 143.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 153.3ms
# Speed: 14.0ms preprocess, 153.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 144.2ms
# Speed: 15.0ms preprocess, 144.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 152.4ms
# Speed: 14.0ms preprocess, 152.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)

# %%
#convert data into neural net input format

X_cropped_train = np.array(X_cropped_train)
y_train_cropped = np.array(y_train_cropped)
X_val_cropped = np.array(X_val_cropped)
y_val_cropped = np.array(y_val_cropped)

# %%
#first convolutional layer
#source of archi: https://cs230.stanford.edu/projects_winter_2020/reports/32610274.pdf

default_filters = 64

input_x = Input(shape = (75, 75, 3))

conv_1 = Conv2D(filters = default_filters, kernel_size = (3, 3), name = 'conv_1', padding = 'same',activation='relu' ,data_format='channels_last')(input_x)
batch_norm1 = BatchNormalization(name = 'batch_norm1')(conv_1)
conv_12 = Conv2D(filters = default_filters, kernel_size = (3, 3), name = 'conv_11', padding = 'same', activation = 'relu')(batch_norm1)#max_pooling
batch_norm12 = BatchNormalization(name = 'batch_norm12')(conv_12)
max_pool1 = MaxPool2D(name = 'max_pool1', pool_size = (2,2), strides = (2,2))(batch_norm12)
drop_out1 = Dropout(0.5)(max_pool1)

#second convolutional layer 
conv2 = Conv2D(filters = 2 * default_filters, kernel_size = (3,3), name = 'conv_2', padding = 'same', activation = 'relu')(drop_out1)
batch_norm2 = BatchNormalization(name = 'batch_norm2')(conv2)
conv21 = Conv2D(filters = 2 * default_filters, kernel_size = (3,3), name = 'conv_21', padding = 'same', activation = 'relu')(conv2)
batch_norm21 = BatchNormalization(name = 'batch_norm21')(conv21)
max_pool2 = MaxPool2D(name = 'max_pool2', pool_size = (2,2), strides = (2,2))(batch_norm21)
dropout_2 = Dropout(0.5)(max_pool2)




#third convolutional layer
conv3 = Conv2D(filters = 2 * 2 * default_filters, kernel_size = (3,3), name = 'conv_3', padding = 'same', activation = 'relu')(dropout_2)
batch_norm3 = BatchNormalization(name = 'batch_norm3')(conv3)
conv31 = Conv2D(filters = 2 * 2 * default_filters, kernel_size = (3,3), name = 'conv_31', padding = 'same', activation = 'relu')(batch_norm3)
batch_norm31 = BatchNormalization(name = 'batch_norm31')(conv31)
max_pool3 = MaxPool2D(name = 'max_pool3', pool_size = (2,2), strides = (2,2))(batch_norm31)
dropout_3 = Dropout(0.5)(max_pool3)

#fourth convolutional layer
conv4 = Conv2D(filters = 2 * 2 * 2 * default_filters, kernel_size = (3,3), name = 'conv_4', padding = 'same', activation = 'relu')(dropout_3)
batch_norm4 = BatchNormalization(name = 'batch_norm4')(conv4)
conv41 = Conv2D(filters = 2 *2 * 2 * default_filters, kernel_size = (3,3), name = 'conv_41', padding = 'same', activation = 'relu')(batch_norm4)
batch_norm41 = BatchNormalization(name = 'batch_norm41')(conv41)
max_pool4 = MaxPool2D(name = 'max_pool4', pool_size = (2,2), strides = (2,2))(batch_norm41)
dropout_4 = Dropout(0.5)(max_pool4)
#dense layer

flat = Flatten()(dropout_4)

dense1 = Dense(256, activation = 'relu', name = 'dense_1')(flat)
drop_out_dense1 = Dropout(0.4)(dense1)
dense2 = Dense(128, activation = 'relu', name = 'dense_2')(drop_out_dense1)
drop_out_dense2 = Dropout(0.4)(dense2)
#final softmax layer
dense3 = Dense(64, activation = 'relu', name = 'dense_3')(drop_out_dense2)
drop_out_dense3 = Dropout(0.5)(dense3)

#6 outputs for the 6 classes
output = Dense(6, activation = 'softmax', name = 'output')(drop_out_dense3)


# In[11]:

# %%
checkpoint = ModelCheckpoint(filepath = 'cnn_scratch.keras')


# In[ ]:


model = Model(input_x, output)

model.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['acc'])

model.fit(x = X_cropped_train, y = y_train_cropped, epochs = 100, validation_data = (X_val_cropped, y_val_cropped), callbacks = [checkpoint])
# Out:
# Epoch 1/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 9s 2s/step - acc: 0.2029 - loss: 6.3720 - val_acc: 0.1429 - val_loss: 6.0598
# Epoch 2/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - acc: 0.1852 - loss: 6.2021 - val_acc: 0.2143 - val_loss: 18.3992
# Epoch 3/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - acc: 0.1353 - loss: 4.8490 - val_acc: 0.1071 - val_loss: 43.3650
# Epoch 4/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - acc: 0.1634 - loss: 4.3505 - val_acc: 0.1429 - val_loss: 53.0017
# Epoch 5/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - acc: 0.1821 - loss: 3.6945 - val_acc: 0.1786 - val_loss: 51.2622
# Epoch 6/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - acc: 0.2175 - loss: 3.6910 - val_acc: 0.1786 - val_loss: 79.2918
# Epoch 7/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - acc: 0.1889 - loss: 3.2117 - val_acc: 0.1786 - val_loss: 49.2311
# Epoch 8/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - acc: 0.2060 - loss: 3.2183 - val_acc: 0.2500 - val_loss: 22.5452
# Epoch 9/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - acc: 0.2102 - loss: 2.6325 - val_acc: 0.1786 - val_loss: 22.5282
# Epoch 10/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - acc: 0.2331 - loss: 2.6162 - val_acc: 0.1786 - val_loss: 21.3317
# Epoch 11/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - acc: 0.1982 - loss: 2.5646 - val_acc: 0.1786 - val_loss: 14.8505
# Epoch 12/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - acc: 0.1795 - loss: 2.5312 - val_acc: 0.1786 - val_loss: 9.8174
# Epoch 13/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - acc: 0.1811 - loss: 2.1561 - val_acc: 0.1786 - val_loss: 7.1971
# Epoch 14/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - acc: 0.1425 - loss: 2.2417 - val_acc: 0.1786 - val_loss: 5.6116
# Epoch 15/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - acc: 0.1967 - loss: 2.1339 - val_acc: 0.1429 - val_loss: 3.9212
# Epoch 16/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - acc: 0.1780 - loss: 2.4367 - val_acc: 0.1429 - val_loss: 2.7489
# Epoch 17/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - acc: 0.1759 - loss: 2.3208 - val_acc: 0.1429 - val_loss: 2.2808
# Epoch 18/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - acc: 0.1930 - loss: 2.3302 - val_acc: 0.1429 - val_loss: 2.0728
# Epoch 19/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - acc: 0.2357 - loss: 2.0690 - val_acc: 0.1429 - val_loss: 1.9140
# Epoch 20/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - acc: 0.1030 - loss: 2.2886 - val_acc: 0.0714 - val_loss: 1.8600
# Epoch 21/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - acc: 0.2206 - loss: 2.2390 - val_acc: 0.1429 - val_loss: 1.8333
# Epoch 22/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - acc: 0.1618 - loss: 2.0893 - val_acc: 0.2143 - val_loss: 1.7887
# Epoch 23/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - acc: 0.2326 - loss: 2.0881 - val_acc: 0.1786 - val_loss: 1.8056
# Epoch 24/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - acc: 0.1972 - loss: 2.2424 - val_acc: 0.1429 - val_loss: 1.8507
# Epoch 25/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - acc: 0.1576 - loss: 2.2459 - val_acc: 0.1071 - val_loss: 1.8452
# Epoch 26/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - acc: 0.1170 - loss: 2.0342 - val_acc: 0.1429 - val_loss: 1.8139
# Epoch 27/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - acc: 0.1629 - loss: 1.9665 - val_acc: 0.1429 - val_loss: 1.7958
# Epoch 28/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - acc: 0.1592 - loss: 2.0480 - val_acc: 0.2143 - val_loss: 1.7987
# Epoch 29/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - acc: 0.2232 - loss: 1.9373 - val_acc: 0.1429 - val_loss: 1.8243
# Epoch 30/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - acc: 0.1847 - loss: 1.9754 - val_acc: 0.1071 - val_loss: 1.8538
# Epoch 31/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - acc: 0.1353 - loss: 2.0588 - val_acc: 0.1429 - val_loss: 1.8380
# Epoch 32/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - acc: 0.2321 - loss: 2.0227 - val_acc: 0.1786 - val_loss: 1.8247
# Epoch 33/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - acc: 0.1191 - loss: 1.8690 - val_acc: 0.1429 - val_loss: 1.8276
# Epoch 34/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - acc: 0.2040 - loss: 1.8448 - val_acc: 0.1429 - val_loss: 1.8363
# Epoch 35/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - acc: 0.1337 - loss: 1.9038 - val_acc: 0.1429 - val_loss: 1.8493
# Epoch 36/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - acc: 0.2097 - loss: 1.8798 - val_acc: 0.1429 - val_loss: 1.8614
# Epoch 37/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - acc: 0.2862 - loss: 1.7833 - val_acc: 0.1429 - val_loss: 1.8857
# Epoch 38/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - acc: 0.1561 - loss: 1.9723 - val_acc: 0.1429 - val_loss: 1.8872
# Epoch 39/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - acc: 0.1358 - loss: 1.8863 - val_acc: 0.1786 - val_loss: 1.8995
# Epoch 40/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - acc: 0.1951 - loss: 1.8699 - val_acc: 0.2143 - val_loss: 1.8849
# Epoch 41/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - acc: 0.2331 - loss: 1.7670 - val_acc: 0.1429 - val_loss: 1.9621
# Epoch 42/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - acc: 0.1488 - loss: 1.8937 - val_acc: 0.1429 - val_loss: 1.9826
# Epoch 43/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - acc: 0.2191 - loss: 1.8286 - val_acc: 0.1071 - val_loss: 1.8903
# Epoch 44/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - acc: 0.2326 - loss: 1.9137 - val_acc: 0.1071 - val_loss: 1.8341
# Epoch 45/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - acc: 0.1790 - loss: 1.7874 - val_acc: 0.1786 - val_loss: 1.7856
# Epoch 46/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - acc: 0.1759 - loss: 1.8452 - val_acc: 0.1071 - val_loss: 1.7936
# Epoch 47/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - acc: 0.2450 - loss: 1.8170 - val_acc: 0.0714 - val_loss: 1.8132
# Epoch 48/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - acc: 0.1555 - loss: 1.8311 - val_acc: 0.0714 - val_loss: 1.8157
# Epoch 49/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - acc: 0.2794 - loss: 1.7898 - val_acc: 0.1071 - val_loss: 1.8269
# Epoch 50/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - acc: 0.1951 - loss: 1.8831 - val_acc: 0.1786 - val_loss: 1.8177
# Epoch 51/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - acc: 0.2482 - loss: 1.7957 - val_acc: 0.1071 - val_loss: 1.8105
# Epoch 52/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - acc: 0.2523 - loss: 1.7315 - val_acc: 0.1071 - val_loss: 1.8120
# Epoch 53/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - acc: 0.2060 - loss: 1.7690 - val_acc: 0.1786 - val_loss: 1.8158
# Epoch 54/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - acc: 0.1561 - loss: 1.7942 - val_acc: 0.1429 - val_loss: 1.8380
# Epoch 55/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - acc: 0.2170 - loss: 1.6842 - val_acc: 0.1429 - val_loss: 1.8524
# Epoch 56/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - acc: 0.2451 - loss: 1.7358 - val_acc: 0.1786 - val_loss: 1.8497
# Epoch 57/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - acc: 0.1790 - loss: 1.7515 - val_acc: 0.1429 - val_loss: 1.8560
# Epoch 58/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - acc: 0.2456 - loss: 1.7160 - val_acc: 0.2143 - val_loss: 1.8384
# Epoch 59/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - acc: 0.2320 - loss: 1.7880 - val_acc: 0.1429 - val_loss: 1.8251
# Epoch 60/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - acc: 0.2461 - loss: 1.7914 - val_acc: 0.1786 - val_loss: 1.8297
# Epoch 61/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - acc: 0.2414 - loss: 1.7259 - val_acc: 0.1786 - val_loss: 1.8339
# Epoch 62/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - acc: 0.2670 - loss: 1.7006 - val_acc: 0.1786 - val_loss: 1.8512
# Epoch 63/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - acc: 0.2560 - loss: 1.7048 - val_acc: 0.1786 - val_loss: 1.8659
# Epoch 64/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - acc: 0.2602 - loss: 1.7385 - val_acc: 0.1786 - val_loss: 1.9001
# Epoch 65/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - acc: 0.2429 - loss: 1.7781 - val_acc: 0.1786 - val_loss: 1.8554
# Epoch 66/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - acc: 0.3236 - loss: 1.6912 - val_acc: 0.1786 - val_loss: 1.8028
# Epoch 67/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - acc: 0.2279 - loss: 1.7754 - val_acc: 0.0357 - val_loss: 1.7995
# Epoch 68/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - acc: 0.2602 - loss: 1.7283 - val_acc: 0.1429 - val_loss: 1.7983
# Epoch 69/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - acc: 0.2659 - loss: 1.7261 - val_acc: 0.2143 - val_loss: 1.7718
# Epoch 70/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - acc: 0.2919 - loss: 1.6851 - val_acc: 0.2500 - val_loss: 1.7660
# Epoch 71/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - acc: 0.2388 - loss: 1.7267 - val_acc: 0.2143 - val_loss: 1.7695
# Epoch 72/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - acc: 0.2081 - loss: 1.6929 - val_acc: 0.2143 - val_loss: 1.7830
# Epoch 73/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - acc: 0.2435 - loss: 1.6845 - val_acc: 0.1786 - val_loss: 1.7855
# Epoch 74/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - acc: 0.2487 - loss: 1.6405 - val_acc: 0.1786 - val_loss: 1.7873
# Epoch 75/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - acc: 0.3632 - loss: 1.6254 - val_acc: 0.1786 - val_loss: 1.7936
# Epoch 76/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - acc: 0.2289 - loss: 1.6683 - val_acc: 0.0714 - val_loss: 1.8044
# Epoch 77/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - acc: 0.2237 - loss: 1.6794 - val_acc: 0.0714 - val_loss: 1.8156
# Epoch 78/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - acc: 0.2497 - loss: 1.6596 - val_acc: 0.1429 - val_loss: 1.8251
# Epoch 79/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - acc: 0.3080 - loss: 1.6782 - val_acc: 0.1071 - val_loss: 1.8603
# Epoch 80/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - acc: 0.3507 - loss: 1.5268 - val_acc: 0.1429 - val_loss: 1.9145
# Epoch 81/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - acc: 0.2497 - loss: 1.6534 - val_acc: 0.1429 - val_loss: 1.9967
# Epoch 82/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - acc: 0.2612 - loss: 1.6100 - val_acc: 0.1786 - val_loss: 2.0714
# Epoch 83/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - acc: 0.2471 - loss: 1.7696 - val_acc: 0.1429 - val_loss: 2.0999
# Epoch 84/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - acc: 0.2903 - loss: 1.5944 - val_acc: 0.1071 - val_loss: 2.1377
# Epoch 85/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 23s 6s/step - acc: 0.3835 - loss: 1.5146 - val_acc: 0.1429 - val_loss: 2.0980
# Epoch 86/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - acc: 0.2357 - loss: 1.6647 - val_acc: 0.2143 - val_loss: 2.0738
# Epoch 87/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - acc: 0.3351 - loss: 1.6838 - val_acc: 0.1071 - val_loss: 1.9503
# Epoch 88/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - acc: 0.3299 - loss: 1.5975 - val_acc: 0.1071 - val_loss: 1.8209
# Epoch 89/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - acc: 0.3267 - loss: 1.6302 - val_acc: 0.2500 - val_loss: 1.7892
# Epoch 90/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 9s 2s/step - acc: 0.2211 - loss: 1.6592 - val_acc: 0.2143 - val_loss: 1.8124
# Epoch 91/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 14s 4s/step - acc: 0.3330 - loss: 1.5818 - val_acc: 0.2143 - val_loss: 1.8217
# Epoch 92/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - acc: 0.3699 - loss: 1.5829 - val_acc: 0.1429 - val_loss: 1.8241
# Epoch 93/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 9s 2s/step - acc: 0.3850 - loss: 1.5136 - val_acc: 0.1429 - val_loss: 1.8280
# Epoch 94/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - acc: 0.2216 - loss: 1.6582 - val_acc: 0.1071 - val_loss: 1.8430
# Epoch 95/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - acc: 0.3772 - loss: 1.5865 - val_acc: 0.2500 - val_loss: 1.8247
# Epoch 96/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - acc: 0.3054 - loss: 1.7091 - val_acc: 0.2143 - val_loss: 1.8139
# Epoch 97/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 9s 2s/step - acc: 0.3195 - loss: 1.6492 - val_acc: 0.2143 - val_loss: 1.8427
# Epoch 98/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - acc: 0.3309 - loss: 1.5554 - val_acc: 0.2500 - val_loss: 1.8769
# Epoch 99/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 9s 2s/step - acc: 0.3829 - loss: 1.5018 - val_acc: 0.1429 - val_loss: 1.9664
# Epoch 100/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - acc: 0.2695 - loss: 1.5789 - val_acc: 0.1786 - val_loss: 2.0314
