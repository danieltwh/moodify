# %%
import numpy as np
#import pandas as pd

import tensorflow.keras as keras
from tensorflow.keras import Model
from tensorflow.keras.callbacks import ModelCheckpoint
from PIL import Image
from sklearn.decomposition import PCA

from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

from ultralytics import YOLO
from matplotlib.pyplot import imshow
import pandas as pd

# %%
train = keras.utils.image_dataset_from_directory(
    directory='../../data/Faces updated',
    labels='inferred',
    label_mode='categorical',
    batch_size=140,
    image_size=(1000, 1000),
    validation_split = 0.2,
    subset = 'training',
    seed = 50,
   
    color_mode = 'grayscale'
    )

validation = keras.utils.image_dataset_from_directory(
    directory='../../data/Faces updated',
    labels='inferred',
    label_mode='categorical',
    batch_size=140,
    image_size=(1000, 1000),
    validation_split = 0.2,
    subset = 'validation',
    seed = 50,
   # class_names = ['Happy', 'Sad', 'Neutral'],
    color_mode = 'grayscale'
    )
# Out:
# Found 154 files belonging to 3 classes.
# Using 124 files for training.
# Found 154 files belonging to 3 classes.
# Using 30 files for validation.

# %%
#convert to numpy images and then perform PCA to extract the values
#convert images to numpy
train_processed_numpy = train.as_numpy_iterator()
validation_processed_numpy = validation.as_numpy_iterator()

X_train, y_train = train_processed_numpy.next()
X_val, y_val = validation_processed_numpy.next()

# %%
#flatten the images
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1] * X_train.shape[2]))
X_val = X_val.reshape((X_val.shape[0], X_val.shape[1] * X_val.shape[2]))

# %%
#Map the high dimensional images to a lower dimension
pca = PCA(n_components = 50)

X_train_lower_dim = pca.fit_transform(X_train)

# %%
pca.explained_variance_ratio_.sum()

#As can be seen from the output below, the first 50 components explain a substantial proportsion of the variance
#include train accuracy as well
# Out:
# 0.94637066

# %%
#fitting an SVC object on this

rf = RandomForestClassifier()

rf.fit(X_train_lower_dim, np.argmax(y_train, axis = 1))
# Out:
# RandomForestClassifier()

# %%
#map the validation set to the lower dimension and then predict using the fitted rf model

X_val_lower_dim = pca.transform(X_val)
y_pred = rf.predict(X_val_lower_dim)

# %%
#computing the accuracy score 

#gives an accuracy score of 0.7! Significantly higher than other classifiers like SVM
accuracy_score(np.argmax(y_val, axis = 1),y_pred)
# Out:
# 0.7

# %%
#see which classes it predicts well

y_val_classes = np.argmax(y_val, axis = 1)

pd.Series(y_val_classes[y_val_classes == y_pred]).value_counts()
# Out:
# 1    10
# 2     7
# 0     5
# Name: count, dtype: int64

# %%
# Out:
# 1    14
# 2    11
# 0     5
# Name: count, dtype: int64

# %% [markdown]
# ### With face cropping

# %%
#try the above but with cropping the face
train = keras.utils.image_dataset_from_directory(
    directory='../../data/Faces updated',
    labels='inferred',
    label_mode='categorical',
    batch_size=140,
    image_size=(1000, 1000),
    validation_split = 0.2,
    subset = 'training',
    seed = 50,
   )

validation = keras.utils.image_dataset_from_directory(
    directory='../../data/Faces updated',
    labels='inferred',
    label_mode='categorical',
    batch_size=140,
    image_size=(1000, 1000),
    validation_split = 0.2,
    subset = 'validation',
    seed = 50,
  
    )
# Out:
# Found 154 files belonging to 3 classes.
# Using 124 files for training.
# Found 154 files belonging to 3 classes.
# Using 30 files for validation.

# %%
#convert to numpy images and then perform PCA to extract the values
#convert images to numpy
train_processed_numpy = train.as_numpy_iterator()
validation_processed_numpy = validation.as_numpy_iterator()

X_train, y_train = train_processed_numpy.next()
X_val, y_val = validation_processed_numpy.next()

# %%
#convert the images to cropped faces
face_classifier = YOLO("../../app/src/face_detection/model/yolov8n-face.pt")

X_cropped_train = []
y_train_cropped = []

n_train = X_train.shape[0]
for i in range(n_train):
    face = X_train[i]
   
    faces = face_classifier.predict(face)
    boxes = faces[0].boxes.xyxy.tolist()
    if boxes:
        
        #extract the face based on the output from the YOLOv8 model        
        left, bottom, right, top = boxes[0]
        cropped_face = face[int(bottom):int(top), int(left):int(right)]
        #resize cropped face to a std shape, 100x100 for now but can adjust this
        pil_face = Image.fromarray(np.uint8(cropped_face))
        pil_face = pil_face.resize((200, 200))
        numpy_cropped_face = np.array(pil_face)
        #append this to the new list containing all cropped faces
        X_cropped_train.append(numpy_cropped_face)
        y_train_cropped.append(y_train[i])

X_val_cropped = []
y_val_cropped = []
n_val = X_val.shape[0]

for i in range(n_val):
    face = X_val[i]
    faces = face_classifier.predict(face)
    boxes = faces[0].boxes.xyxy.tolist()
    if boxes:
        
        #extract the face based on the output from the YOLOv8 model        
        left, bottom, right, top = boxes[0]
        cropped_face = face[int(bottom):int(top), int(left):int(right)]
        #resize cropped face to a std shape, 100x100 for now but can adjust this
        pil_face = Image.fromarray(np.uint8(cropped_face))
        pil_face = pil_face.resize((200, 200))
        numpy_cropped_face = np.array(pil_face)
        #append this to the new list containing all cropped faces
        X_val_cropped.append(numpy_cropped_face)
        y_val_cropped.append(y_val[i])
# Out:
# 0: 640x640 1 face, 148.2ms
# Speed: 19.8ms preprocess, 148.2ms inference, 3.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 96.8ms
# Speed: 4.8ms preprocess, 96.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 77.7ms
# Speed: 18.4ms preprocess, 77.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 79.2ms
# Speed: 20.1ms preprocess, 79.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 75.0ms
# Speed: 10.1ms preprocess, 75.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 93.8ms
# Speed: 9.9ms preprocess, 93.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 faces, 92.5ms
# Speed: 12.0ms preprocess, 92.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 91.7ms
# Speed: 20.6ms preprocess, 91.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 83.1ms
# Speed: 16.6ms preprocess, 83.1ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 84.3ms
# Speed: 16.6ms preprocess, 84.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 112.5ms
# Speed: 15.4ms preprocess, 112.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 83.7ms
# Speed: 15.9ms preprocess, 83.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 83.4ms
# Speed: 16.9ms preprocess, 83.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 92.8ms
# Speed: 17.3ms preprocess, 92.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 81.7ms
# Speed: 17.3ms preprocess, 81.7ms inference, 15.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 94.0ms
# Speed: 13.5ms preprocess, 94.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 81.7ms
# Speed: 13.3ms preprocess, 81.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 100.3ms
# Speed: 21.8ms preprocess, 100.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 97.7ms
# Speed: 2.7ms preprocess, 97.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 78.2ms
# Speed: 22.2ms preprocess, 78.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 78.5ms
# Speed: 16.0ms preprocess, 78.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 79.2ms
# Speed: 24.1ms preprocess, 79.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 95.7ms
# Speed: 43.5ms preprocess, 95.7ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 101.7ms
# Speed: 26.6ms preprocess, 101.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 83.4ms
# Speed: 32.9ms preprocess, 83.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 81.4ms
# Speed: 30.2ms preprocess, 81.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 85.7ms
# Speed: 28.0ms preprocess, 85.7ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 81.8ms
# Speed: 14.1ms preprocess, 81.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 85.5ms
# Speed: 12.0ms preprocess, 85.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 88.1ms
# Speed: 15.3ms preprocess, 88.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 82.0ms
# Speed: 3.2ms preprocess, 82.0ms inference, 11.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 86.6ms
# Speed: 10.0ms preprocess, 86.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 87.0ms
# Speed: 13.4ms preprocess, 87.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 95.6ms
# Speed: 5.9ms preprocess, 95.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 87.5ms
# Speed: 11.1ms preprocess, 87.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 89.4ms
# Speed: 11.1ms preprocess, 89.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 97.6ms
# Speed: 1.7ms preprocess, 97.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 90.4ms
# Speed: 9.2ms preprocess, 90.4ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 96.8ms
# Speed: 0.0ms preprocess, 96.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 91.0ms
# Speed: 18.4ms preprocess, 91.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 89.7ms
# Speed: 13.2ms preprocess, 89.7ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 83.8ms
# Speed: 11.6ms preprocess, 83.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 97.5ms
# Speed: 2.6ms preprocess, 97.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 85.8ms
# Speed: 11.4ms preprocess, 85.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 86.0ms
# Speed: 15.8ms preprocess, 86.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 98.6ms
# Speed: 1.5ms preprocess, 98.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 85.7ms
# Speed: 11.1ms preprocess, 85.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 83.9ms
# Speed: 16.5ms preprocess, 83.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 90.8ms
# Speed: 21.6ms preprocess, 90.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 81.2ms
# Speed: 11.3ms preprocess, 81.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 85.2ms
# Speed: 21.8ms preprocess, 85.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 99.3ms
# Speed: 3.7ms preprocess, 99.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 84.4ms
# Speed: 7.5ms preprocess, 84.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 96.1ms
# Speed: 4.9ms preprocess, 96.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 118.3ms
# Speed: 1.4ms preprocess, 118.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 86.6ms
# Speed: 13.5ms preprocess, 86.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 80.7ms
# Speed: 15.0ms preprocess, 80.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 86.8ms
# Speed: 15.8ms preprocess, 86.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 79.6ms
# Speed: 16.0ms preprocess, 79.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 75.5ms
# Speed: 21.1ms preprocess, 75.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 92.9ms
# Speed: 23.2ms preprocess, 92.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 96.1ms
# Speed: 0.3ms preprocess, 96.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 77.4ms
# Speed: 11.8ms preprocess, 77.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 90.5ms
# Speed: 22.6ms preprocess, 90.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 85.5ms
# Speed: 17.1ms preprocess, 85.5ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 74.4ms
# Speed: 16.3ms preprocess, 74.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 94.7ms
# Speed: 7.6ms preprocess, 94.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 97.1ms
# Speed: 0.0ms preprocess, 97.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 76.3ms
# Speed: 17.7ms preprocess, 76.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 91.7ms
# Speed: 7.7ms preprocess, 91.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 82.0ms
# Speed: 4.8ms preprocess, 82.0ms inference, 15.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 79.3ms
# Speed: 14.9ms preprocess, 79.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 99.9ms
# Speed: 6.8ms preprocess, 99.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 101.1ms
# Speed: 12.0ms preprocess, 101.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 82.3ms
# Speed: 11.0ms preprocess, 82.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 100.5ms
# Speed: 15.6ms preprocess, 100.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 91.7ms
# Speed: 15.6ms preprocess, 91.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 86.1ms
# Speed: 10.0ms preprocess, 86.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 93.0ms
# Speed: 2.3ms preprocess, 93.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 96.0ms
# Speed: 25.3ms preprocess, 96.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 82.4ms
# Speed: 17.2ms preprocess, 82.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 84.9ms
# Speed: 15.6ms preprocess, 84.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 99.2ms
# Speed: 0.0ms preprocess, 99.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 84.9ms
# Speed: 10.5ms preprocess, 84.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 102.9ms
# Speed: 15.7ms preprocess, 102.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 93.0ms
# Speed: 11.6ms preprocess, 93.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 98.0ms
# Speed: 14.3ms preprocess, 98.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 98.4ms
# Speed: 17.8ms preprocess, 98.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 83.2ms
# Speed: 17.0ms preprocess, 83.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 84.7ms
# Speed: 16.4ms preprocess, 84.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 82.4ms
# Speed: 24.2ms preprocess, 82.4ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 77.1ms
# Speed: 13.4ms preprocess, 77.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 105.5ms
# Speed: 8.9ms preprocess, 105.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 84.8ms
# Speed: 16.8ms preprocess, 84.8ms inference, 13.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 85.1ms
# Speed: 11.5ms preprocess, 85.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 122.5ms
# Speed: 3.3ms preprocess, 122.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 95.3ms
# Speed: 19.8ms preprocess, 95.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 89.4ms
# Speed: 8.7ms preprocess, 89.4ms inference, 15.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 85.4ms
# Speed: 11.7ms preprocess, 85.4ms inference, 14.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 97.4ms
# Speed: 15.4ms preprocess, 97.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 102.2ms
# Speed: 16.3ms preprocess, 102.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 99.7ms
# Speed: 14.3ms preprocess, 99.7ms inference, 15.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 100.4ms
# Speed: 17.2ms preprocess, 100.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 103.5ms
# Speed: 29.7ms preprocess, 103.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 112.5ms
# Speed: 25.3ms preprocess, 112.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 95.3ms
# Speed: 15.5ms preprocess, 95.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 105.4ms
# Speed: 15.4ms preprocess, 105.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 90.9ms
# Speed: 13.4ms preprocess, 90.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 94.4ms
# Speed: 5.5ms preprocess, 94.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 115.8ms
# Speed: 4.2ms preprocess, 115.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 114.1ms
# Speed: 18.6ms preprocess, 114.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 104.5ms
# Speed: 12.9ms preprocess, 104.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 105.0ms
# Speed: 8.3ms preprocess, 105.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 106.4ms
# Speed: 16.2ms preprocess, 106.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 100.7ms
# Speed: 9.9ms preprocess, 100.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 114.7ms
# Speed: 6.9ms preprocess, 114.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 106.4ms
# Speed: 12.8ms preprocess, 106.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 105.9ms
# Speed: 20.6ms preprocess, 105.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 106.3ms
# Speed: 11.0ms preprocess, 106.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 103.3ms
# Speed: 14.8ms preprocess, 103.3ms inference, 5.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 114.6ms
# Speed: 3.5ms preprocess, 114.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 98.4ms
# Speed: 12.3ms preprocess, 98.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 115.7ms
# Speed: 0.0ms preprocess, 115.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 106.0ms
# Speed: 15.9ms preprocess, 106.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 112.0ms
# Speed: 6.5ms preprocess, 112.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 101.4ms
# Speed: 11.3ms preprocess, 101.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 99.1ms
# Speed: 1.2ms preprocess, 99.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 84.1ms
# Speed: 16.4ms preprocess, 84.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 84.3ms
# Speed: 15.7ms preprocess, 84.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 100.2ms
# Speed: 0.0ms preprocess, 100.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 83.9ms
# Speed: 16.3ms preprocess, 83.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 97.5ms
# Speed: 0.0ms preprocess, 97.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 100.2ms
# Speed: 0.0ms preprocess, 100.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 85.1ms
# Speed: 14.8ms preprocess, 85.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 83.6ms
# Speed: 16.6ms preprocess, 83.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 100.6ms
# Speed: 2.5ms preprocess, 100.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 83.9ms
# Speed: 15.8ms preprocess, 83.9ms inference, 13.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 100.0ms
# Speed: 0.0ms preprocess, 100.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 103.8ms
# Speed: 3.3ms preprocess, 103.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 99.9ms
# Speed: 0.0ms preprocess, 99.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 99.9ms
# Speed: 16.7ms preprocess, 99.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 96.9ms
# Speed: 18.5ms preprocess, 96.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 92.0ms
# Speed: 19.2ms preprocess, 92.0ms inference, 5.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 99.7ms
# Speed: 0.0ms preprocess, 99.7ms inference, 15.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 102.8ms
# Speed: 15.7ms preprocess, 102.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 99.8ms
# Speed: 17.3ms preprocess, 99.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 98.5ms
# Speed: 15.8ms preprocess, 98.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 110.8ms
# Speed: 0.0ms preprocess, 110.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 94.7ms
# Speed: 0.0ms preprocess, 94.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 101.5ms
# Speed: 0.0ms preprocess, 101.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 102.1ms
# Speed: 16.1ms preprocess, 102.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 83.7ms
# Speed: 15.7ms preprocess, 83.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 101.2ms
# Speed: 0.0ms preprocess, 101.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 face, 82.9ms
# Speed: 11.6ms preprocess, 82.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)

# %%
#convert the lists to np arrays
X_cropped_train = np.array(X_cropped_train)

X_val_cropped = np.array(X_val_cropped)

# %%
#Flatten the RGB image into a flat tensor


X_cropped_train = X_cropped_train.reshape((X_cropped_train.shape[0], X_cropped_train.shape[1] * X_cropped_train.shape[2] * X_cropped_train.shape[3]))
X_val_cropped = X_val_cropped.reshape((X_val_cropped.shape[0], X_val_cropped.shape[1] * X_val_cropped.shape[2] * X_val_cropped.shape[3]))


y_train_lab = np.array(y_train_cropped).argmax(axis = 1)
y_val_lab = np.array(y_val_cropped).argmax(axis = 1)

# %%
#apply PCA to map to a lower dimension
pca = PCA(n_components = 50)

X_train_lower_dim = pca.fit_transform(X_cropped_train)

# %%
rf_cropped = RandomForestClassifier()

#train on the lower dimensions of the data
rf_cropped.fit(X_train_lower_dim, y_train_lab)
# Out:
# RandomForestClassifier()

# %%
#compute training accuracy
y_train_pred = rf_cropped.predict(X_train_lower_dim)

#acheives perfect score on the training data, could be a sign of overfitting
print(accuracy_score(y_train_lab, y_train_pred))
# Out:
# 1.0

# %%
#map the validation data to a lower dimension based on the data
X_val_cropped_lower_dim = pca.transform(X_val_cropped)

# %%
y_pred = rf_cropped.predict(X_val_cropped_lower_dim)
#display the accuracy of the model
print(accuracy_score(y_val_lab, y_pred))
#note that the accuracy is lower compared to not using the cropped image
# Out:
# 0.5
